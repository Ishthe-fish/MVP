# %% [markdown]
# # Core Problem
# ### Identify duplicate or matching individuals across CSVs with messy data

# %%
import pandas as pd
import requests

df_g = pd.read_csv("general")
df_p = pd.read_csv("political")

# %%
df_g.head(3)
# Out:
#        fname    lname         dob full_address         city state  \
# 0       John    Smith  1985-04-12  123 Main St  Springfield    IL
# 1  Elizabeth    Jones  1990-07-23   45 Oak Ave       Boston    MA
# 2       Mike  Johnson  1982-11-01  789 Pine Rd       Austin    TX
#
#                        email
# 0       john.smith@gmail.com
# 1  elizabeth.jones@yahoo.com
# 2           mike.j@gmail.com

# %%
df_p.head(3)
# Out:
#      fname    lname         dob  zipcode         city state  \
# 0      Jon    Smith  1985-04-12    62704  Springfield    IL
# 1      Liz    Jones  1990-07-23     2116       Boston    MA
# 2  Michael  Johnson  1982-11-01    78745       Austin    TX
#
#   political_affiliation                      email
# 0           Independent       john.smith@gmail.com
# 1              Democrat  elizabeth.jones@yahoo.com
# 2            Republican           mike.j@gmail.com

# %%
# Below is Data prep
for col in df_p.columns:            #looping through col
    for i in range(len(df_p[col])):  #Loop through each row in that col
        value = df_p.at[i,col]       # get the value
        if isinstance(value,str):    #check if its a string
            df_p.at[i,col] = value.lower().strip()  #make it lower and remoces white space


for col in df_g.columns:            #looping through col
    for i in range(len(df_g[col])):  #Loop through each row in that col
        value = df_g.at[i,col]       # get the value
        if isinstance(value,str):    #check if its a string
            df_g.at[i,col] = value.lower().strip() #make it lower and removes white space

# %%
df_g.head(3)
# Out:
#        fname    lname         dob full_address         city state  \
# 0       john    smith  1985-04-12  123 main st  springfield    il
# 1  elizabeth    jones  1990-07-23   45 oak ave       boston    ma
# 2       mike  johnson  1982-11-01  789 pine rd       austin    tx
#
#                        email
# 0       john.smith@gmail.com
# 1  elizabeth.jones@yahoo.com
# 2           mike.j@gmail.com

# %%
df_p.head(3)
# Out:
#      fname    lname         dob  zipcode         city state  \
# 0      jon    smith  1985-04-12    62704  springfield    il
# 1      liz    jones  1990-07-23     2116       boston    ma
# 2  michael  johnson  1982-11-01    78745       austin    tx
#
#   political_affiliation                      email
# 0           independent       john.smith@gmail.com
# 1              democrat  elizabeth.jones@yahoo.com
# 2            republican           mike.j@gmail.com

# %%
#creating a index column so when we do union we can see original location
def index_og(df):
    df['og_loc'] = df.index
    return df

# %%
df_p = index_og(df_p)
df_g = index_og(df_g)

# %%
#have to add a part on how to handle nulls ? might not need to have to think about it

# %%
#Here have to add a part where they tell us what columns to select and we pull those columns
#no need to pull all the data since we will just refer to them by their 'og_loc' number

# %%
compr_df = pd.concat([df_g[['fname','lname','dob','state','og_loc']],df_p[['fname','lname','dob','state','og_loc']]], axis =0)
compr_df.head()
# Out:
#        fname     lname         dob state  og_loc
# 0       john     smith  1985-04-12    il       0
# 1  elizabeth     jones  1990-07-23    ma       1
# 2       mike   johnson  1982-11-01    tx       2
# 3      sarah  williams  1995-02-19    co       3
# 4     robert     brown  1978-09-03    wa       4

# %%
compr_df['fname'].iloc[0][0:3]
# Out:
# 'joh'

# %%
cols_to_use = ['fname', 'lname', 'dob', 'state']  # choose which columns to include

compr_df['combo_code1'] = ''  # start with empty strings
compr_df['combo_code2'] = ''  # start with empty strings
compr_df['combo_code3'] = ''  # start with empty strings

for col in cols_to_use:
    compr_df['combo_code1'] += compr_df[col].str[:3].fillna('')
    
for col in cols_to_use:
    compr_df['combo_code2'] += compr_df[col].str[:4].fillna('')

for col in cols_to_use:
    compr_df['combo_code3'] += compr_df[col].str[:5].fillna('')

# %%
compr_df.head(5)
# Out:
#        fname     lname         dob state  og_loc combo_code  combo_code1  \
# 0       john     smith  1985-04-12    il       0             johsmi198il
# 1  elizabeth     jones  1990-07-23    ma       1             elijon199ma
# 2       mike   johnson  1982-11-01    tx       2             mikjoh198tx
# 3      sarah  williams  1995-02-19    co       3             sarwil199co
# 4     robert     brown  1978-09-03    wa       4             robbro197wa
#
#       combo_code2        combo_code3
# 0  johnsmit1985il   johnsmith1985-il
# 1  elizjone1990ma  elizajones1990-ma
# 2  mikejohn1982tx   mikejohns1982-tx
# 3  sarawill1995co  sarahwilli1995-co
# 4  robebrow1978wa  roberbrown1978-wa

# %%
compr_df['dup_flag1'] = compr_df['combo_code1'].duplicated(keep=False).astype(int)
compr_df['dup_flag2'] = compr_df['combo_code2'].duplicated(keep=False).astype(int)
compr_df['dup_flag3'] = compr_df['combo_code3'].duplicated(keep=False).astype(int)

# %%
compr_df.sort_values(by=['dup_flag3','dup_flag2','dup_flag1'], ascending = False)
# Out:
#         fname     lname         dob state  og_loc combo_code  combo_code1  \
# 4      robert     brown  1978-09-03    wa       4             robbro197wa
# 5       emily     davis  1989-12-25    or       5             emidav198or
# 6       chris    miller  1992-06-30    oh       6             chrmil199oh
# 7     jessica    wilson  1986-01-14    fl       7             jeswil198fl
# 10       jake  anderson  1987-05-10    ca      10             jakand198ca
# 11      laura    thomas  1993-09-29    tx      11             lautho199tx
# 12      david   jackson  1980-10-05    az      12             davjac198az
# 13      megan     white  1996-12-01    id      13             megwhi199id
# 15     rachel    martin  1992-07-02    nv      15             racmar199nv
# 16    william  thompson  1975-02-20    fl      16             wiltho197fl
# 19     hannah     lewis  1997-08-13    fl      19             hanlew199fl
# 4      robert     brown  1978-09-03    wa       4             robbro197wa
# 5       emily     davis  1989-12-25    or       5             emidav198or
# 6       chris    miller  1992-06-30    oh       6             chrmil199oh
# 7     jessica    wilson  1986-01-14    fl       7             jeswil198fl
# 10       jake  anderson  1987-05-10    ca      10             jakand198ca
# 11      laura    thomas  1993-09-29    tx      11             lautho199tx
# 12      david   jackson  1980-10-05    az      12             davjac198az
# 13      megan     white  1996-12-01    id      13             megwhi199id
# 15     rachel    martin  1992-07-02    nv      15             racmar199nv
# 16    william  thompson  1975-02-20    fl      16             wiltho197fl
# 19     hannah     lewis  1997-08-13    fl      19             hanlew199fl
# 3       sarah  williams  1995-02-19    co       3             sarwil199co
# 8     matthew     moore  1983-08-08    il       8             matmoo198il
# 3        sara  williams  1995-02-19    co       3             sarwil199co
# 8        matt     moore  1983-08-08    il       8             matmoo198il
# 9      ashley    taylor  1991-03-17    ga       9             ashtay199ga
# 17     daniel    garcia  1988-11-09    ca      17             dangar198ca
# 18   nicholas     clark  1994-05-25    nc      18             niccla199nc
# 9         ash    taylor  1991-03-17    ga       9             ashtay199ga
# 17        dan    garcia  1988-11-09    ca      17             dangar198ca
# 18       nick     clark  1994-05-25    nc      18             niccla199nc
# 0        john     smith  1985-04-12    il       0             johsmi198il
# 1   elizabeth     jones  1990-07-23    ma       1             elijon199ma
# 2        mike   johnson  1982-11-01    tx       2             mikjoh198tx
# 14    anthony    harris  1984-04-22    tn      14             anthar198tn
# 0         jon     smith  1985-04-12    il       0             jonsmi198il
# 1         liz     jones  1990-07-23    ma       1             lizjon199ma
# 2     michael   johnson  1982-11-01    tx       2             micjoh198tx
# 14       tony    harris  1984-04-22    tn      14             tonhar198tn
#
#        combo_code2        combo_code3  dup_flag1  dup_flag2  dup_flag3
# 4   robebrow1978wa  roberbrown1978-wa          1          1          1
# 5   emildavi1989or  emilydavis1989-or          1          1          1
# 6   chrimill1992oh  chrismille1992-oh          1          1          1
# 7   jesswils1986fl  jessiwilso1986-fl          1          1          1
# 10  jakeande1987ca   jakeander1987-ca          1          1          1
# 11  laurthom1993tx  laurathoma1993-tx          1          1          1
# 12  davijack1980az  davidjacks1980-az          1          1          1
# 13  megawhit1996id  meganwhite1996-id          1          1          1
# 15  rachmart1992nv  rachemarti1992-nv          1          1          1
# 16  willthom1975fl  willithomp1975-fl          1          1          1
# 19  hannlewi1997fl  hannalewis1997-fl          1          1          1
# 4   robebrow1978wa  roberbrown1978-wa          1          1          1
# 5   emildavi1989or  emilydavis1989-or          1          1          1
# 6   chrimill1992oh  chrismille1992-oh          1          1          1
# 7   jesswils1986fl  jessiwilso1986-fl          1          1          1
# 10  jakeande1987ca   jakeander1987-ca          1          1          1
# 11  laurthom1993tx  laurathoma1993-tx          1          1          1
# 12  davijack1980az  davidjacks1980-az          1          1          1
# 13  megawhit1996id  meganwhite1996-id          1          1          1
# 15  rachmart1992nv  rachemarti1992-nv          1          1          1
# 16  willthom1975fl  willithomp1975-fl          1          1          1
# 19  hannlewi1997fl  hannalewis1997-fl          1          1          1
# 3   sarawill1995co  sarahwilli1995-co          1          1          0
# 8   mattmoor1983il  matthmoore1983-il          1          1          0
# 3   sarawill1995co   sarawilli1995-co          1          1          0
# 8   mattmoor1983il   mattmoore1983-il          1          1          0
# 9   ashltayl1991ga  ashletaylo1991-ga          1          0          0
# 17  danigarc1988ca  daniegarci1988-ca          1          0          0
# 18  nichclar1994nc  nichoclark1994-nc          1          0          0
# 9    ashtayl1991ga    ashtaylo1991-ga          1          0          0
# 17   dangarc1988ca    dangarci1988-ca          1          0          0
# 18  nickclar1994nc   nickclark1994-nc          1          0          0
# 0   johnsmit1985il   johnsmith1985-il          0          0          0
# 1   elizjone1990ma  elizajones1990-ma          0          0          0
# 2   mikejohn1982tx   mikejohns1982-tx          0          0          0
# 14  anthharr1984tn  anthoharri1984-tn          0          0          0
# 0    jonsmit1985il    jonsmith1985-il          0          0          0
# 1    lizjone1990ma    lizjones1990-ma          0          0          0
# 2   michjohn1982tx  michajohns1982-tx          0          0          0
# 14  tonyharr1984tn   tonyharri1984-tn          0          0          0
